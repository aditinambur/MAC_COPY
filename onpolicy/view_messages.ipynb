# %%
import numpy as np
import os
from pathlib import Path
import json
from pprint import pprint

# %%
# Update this path to point to your .npy file
npy_file_path = "scripts/results/MPE/simple_spread/mappo/check/wandb/offline-run-20260321_222639-9kwppk2g/files/messages/episode_000000_step_0000_messages.npy"

# Convert to absolute or check if relative path exists
if not os.path.isabs(npy_file_path):
    npy_file_path = os.path.join(os.getcwd(), npy_file_path)

print(f"Loading file: {npy_file_path}")
print(f"File exists: {os.path.exists(npy_file_path)}")
# Out:
# Loading file: c:\Users\aditi\PES\python\cnproj\GitCode\CAPSTONE-PROJECT\onpolicy\scripts/results/MPE/simple_spread/mappo/check/wandb/offline-run-20260321_222639-9kwppk2g/files/messages/episode_000000_step_0000_messages.npy
# File exists: True

# %%
# Load the numpy array
messages_array = np.load(npy_file_path)
print(f"Successfully loaded numpy array")
# Out:
# Successfully loaded numpy array

# %%
# Display metadata
file_stat = os.stat(npy_file_path)

print("=" * 70)
print("FILE METADATA")
print("=" * 70)
print(f"File size: {file_stat.st_size} bytes ({file_stat.st_size / 1024:.2f} KB)")
print(f"File path: {npy_file_path}")
print()

print("=" * 70)
print("ARRAY INFORMATION")
print("=" * 70)
print(f"Array shape: {messages_array.shape}")
print(f"Data type: {messages_array.dtype}")
print(f"Total elements: {messages_array.size}")
print(f"Memory size: {messages_array.nbytes / 1024:.2f} KB")
print(f"Min value: {messages_array.min():.6f}")
print(f"Max value: {messages_array.max():.6f}")
print(f"Mean value: {messages_array.mean():.6f}")
print(f"Std deviation: {messages_array.std():.6f}")
print()
# Out:
# ======================================================================
# FILE METADATA
# ======================================================================
# File size: 16512 bytes (16.12 KB)
# File path: c:\Users\aditi\PES\python\cnproj\GitCode\CAPSTONE-PROJECT\onpolicy\scripts/results/MPE/simple_spread/mappo/check/wandb/offline-run-20260321_222639-9kwppk2g/files/messages/episode_000000_step_0000_messages.npy
#
# ======================================================================
# ARRAY INFORMATION
# ======================================================================
# Array shape: (32, 2, 64)
# Data type: float32
# Total elements: 4096
# Memory size: 16.00 KB
# Min value: -0.870425
# Max value: 4.970930
# Mean value: 0.000000
# Std deviation: 0.999867

# %%
print("=" * 70)
print("ARRAY CONTENTS (First 100 elements)")
print("=" * 70)
# Flatten to 1D for easier inspection
flat_view = messages_array.flatten()[:100]
print(f"Flattened view (first 100 elements):")
np.set_printoptions(precision=6, suppress=True, linewidth=100)
print(flat_view)
print()

print("=" * 70)
print("FULL ARRAY VIEW")
print("=" * 70)
print("Shape breakdown:")
print(f"  Dimension 0 (n_envs or n_agents): {messages_array.shape[0]}")
if len(messages_array.shape) > 1:
    print(f"  Dimension 1: {messages_array.shape[1]}")
if len(messages_array.shape) > 2:
    print(f"  Dimension 2 (message_dim): {messages_array.shape[2]}")
print()
print("Array preview:")
print(messages_array)
# Out:
# ======================================================================
# ARRAY CONTENTS (First 100 elements)
# ======================================================================
# Flattened view (first 100 elements):
# [ 0.213991 -0.678982  0.487483 -0.678982 -0.000769  1.778716 -0.678982 -0.678982  0.469785
#   0.102653 -0.1623   -0.678982 -0.678982 -0.678982 -0.678982  0.065863  1.410167 -0.678982
#  -0.678982  1.557053 -0.678982 -0.05727   0.290336 -0.263208 -0.678982 -0.678982  0.815228
#  -0.678982  1.557239 -0.626382 -0.678982 -0.678982  1.450022 -0.678982  3.400393 -0.678982
#  -0.678982 -0.678982 -0.678982  1.860161 -0.678982 -0.678982  1.031793 -0.508167 -0.2409
#  -0.45314  -0.678982 -0.678982  2.278576  0.848699  1.145994 -0.678982 -0.678982 -0.678982
#  -0.678982 -0.645864 -0.334336  1.427565 -0.678982  0.668829 -0.678982 -0.678982 -0.678982
#   2.838187 -0.699195 -0.699195 -0.699195 -0.699195 -0.458789 -0.699195 -0.699195 -0.699195
#  -0.647479  0.41707  -0.699195 -0.600108  0.037812  1.892594  1.19935  -0.699195 -0.138149
#  -0.44456   1.117674 -0.699195  1.326286  0.691556 -0.591443 -0.699195  0.409819 -0.434982
#  -0.699195  0.917138 -0.699195 -0.699195  1.265244  1.618645 -0.699195  0.086171 -0.699195
#  -0.699195]
#
# ======================================================================
# FULL ARRAY VIEW
# ======================================================================
# Shape breakdown:
#   Dimension 0 (n_envs or n_agents): 32
#   Dimension 1: 2
#   Dimension 2 (message_dim): 64
#
# Array preview:
# [[[ 0.213991 -0.678982  0.487483 ... -0.678982 -0.678982  2.838187]
#   [-0.699195 -0.699195 -0.699195 ...  1.249499  0.233149 -0.699195]]
#
#  [[-0.705727 -0.26298  -0.571602 ...  1.200491 -0.705727 -0.705727]
#   [-0.6642   -0.6642   -0.645669 ...  1.398575 -0.6642   -0.6642  ]]
#
#  [[-0.723211  0.917591 -0.723211 ...  0.640684  1.693854 -0.723211]
#   [ 0.24907  -0.60349   0.848416 ... -0.60349  -0.60349   3.513704]]
#
#  ...
#
#  [[ 0.019079  1.661931  0.953226 ... -0.646392  1.412756  0.425128]
#   [-0.70368   1.486982  0.921872 ... -0.70368   2.075608  1.104908]]
#
#  [[ 0.324462  1.770828 -0.695461 ... -0.695461  0.344936 -0.695461]
#   [ 0.901864 -0.630205  0.698686 ... -0.630205 -0.630205  1.617612]]
#
#  [[-0.665767 -0.665767  0.40544  ...  1.483409 -0.665767 -0.00055 ]
#   [-0.684681 -0.684681 -0.619159 ...  1.381976 -0.684681  0.321675]]]
